# %%
import pandas as pd
import os

network_path = 's3://mot-non-production-simulations/applications/pt_variations_2018/outputs_baseline_2018/output_network.xml.gz'
output_path = "/Users/tszchun.chow/Documents/Monty_Materials/link_table.csv"
region_join = " --join /Users/tszchun.chow/Documents/GitHub/monty-reporting/regions/regional_council.geojson"

os.system(f"monty-reporting network -n {network_path} -o {output_path}" + region_join)
# Out:
# Running network conversion...
# Error: Could not load network from path '"s3://mot-non-production-simulations/applications/pt_variations_2018/outputs_baseline_2018/output_network.xml.gz"'
#
# Caused by:
#     0: Could not create file handle for reading
#     1: No such file or directory (os error 2)
# 256

# %%
s3_dir = "s3://mot-non-production-simulations/applications/pt_variations_2018/"
s3_analysis_dir = s3_dir + "analysis/"
scenarios = ["baseline_2018"]
for scen in scenarios:
    s3_final_dir = s3_analysis_dir + scen + "/"
    #os.system(f"aws s3api put-object --bucket analysis --key folder-name/ --content-length 0")
    print(f"aws s3 cp /Users/tszchun.chow/Documents/Monty_Materials/pt_variations_2018/analysis/baseline_2018 {s3_final_dir} --recursive")
# Out:
# aws s3 cp /Users/tszchun.chow/Documents/Monty_Materials/pt_variations_2018/analysis/baseline_2018 s3://mot-non-production-simulations/applications/pt_variations_2018/analysis/baseline_2018/ --recursive

# %%
import pandas as pd
csv = pd.read_parquet(r'/Users/tszchun.chow/Documents/Monty_Materials/pt_variations_2018/analysis/2018_metrics_speed.parquet')

# %%
csv.to_csv(r'/Users/tszchun.chow/Documents/Monty_Materials/pt_variations_2018/analysis/2018_metrics_speed.csv', index=None)

# %%
csv
# Out:
#               Group period mode trip_purpose         area_type  \
# 0           Network      -   pv         None  regional_council
# 1           Network      -   pv         None  regional_council
# 2           Network      -   pv         None  regional_council
# 3           Network      -   pv         None  regional_council
# 4           Network      -   pv         None  regional_council
# ...             ...    ...  ...          ...               ...
# 1994769  Trips (OD)     PM   pv         None               sa2
# 1994770  Trips (OD)     PM   pv         None               sa2
# 1994771  Trips (OD)     PM   pv         None               sa2
# 1994772  Trips (OD)     PM   pv         None               sa2
# 1994773  Trips (OD)     PM   pv         None               sa2
#
#                          area       start_area              end_area  \
# 0             Auckland Region             None                  None
# ...

# %%
# !pip install vega_datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.8/210.8 kB 4.5 MB/s eta 0:00:00a 0:00:01
# ...

# %%
from vega_datasets import data

source = data.seattle_weather()
source
# Out:
#            date  precipitation  temp_max  temp_min  wind  weather
# 0    2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1    2012-01-02           10.9      10.6       2.8   4.5     rain
# 2    2012-01-03            0.8      11.7       7.2   2.3     rain
# 3    2012-01-04           20.3      12.2       5.6   4.7     rain
# 4    2012-01-05            1.3       8.9       2.8   6.1     rain
# ...         ...            ...       ...       ...   ...      ...
# 1456 2015-12-27            8.6       4.4       1.7   2.9      fog
# 1457 2015-12-28            1.5       5.0       1.7   1.3      fog
# 1458 2015-12-29            0.0       7.2       0.6   2.6      fog
# 1459 2015-12-30            0.0       5.6      -1.0   3.4      sun
# 1460 2015-12-31            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 6 columns]
