# %%
import pandas as pd
import os
from pathlib import Path
import logging
import warnings
import itertools

from utils import *

warnings.filterwarnings("ignore")

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - [%(filename)s:%(lineno)d] - %(message)s",
)

# %%
MODE_MAPPING = {
    "car": "pv",
    "car_passenger": "pv",
    "bus": "pt",
    "rail": "pt",
    "ferry": "pt",
    "walk": "active",
    "bike": "active",
    "freight": "freight",
    "lightrail": "pt",
    "rail": "pt",
    "train": "pt",
}

def read_trips(scenario_path) -> pd.DataFrame:
    df = pd.read_csv(os.path.join(scenario_path, "trips.csv"), low_memory=False)
    persons = pd.read_csv(os.path.join(scenario_path, "synthetic_persons.csv"), low_memory=False)
    persons = persons[['person_id', 'household_id', 'home_region', 'sa2', 'age', 'gender', 
                       'labour_force_status', 'student_status', 'hh_size', 'car_availability', 
                       'is_working_from_home', 'income_group']] #select important columns
    persons['age_group'] = persons["age"].apply(get_age_group)
    persons = persons.rename(columns={'sa2': 'home_sa2'})
    
    df['person'] = df['person'].astype(str)
    persons['person_id'] = persons['person_id'].astype(str)

    df = df.merge(persons, left_on='person', right_on = 'person_id', how='left')
    distance_bins = range(0, 40, 1)

    df["dep_time"] = (df["dep_time"].apply(get_sec)) / 3600
    df["trav_time"] = (df["trav_time"].apply(get_sec)) / 3600
    df["period"] = df["dep_time"].apply(get_time_period)
    df["traveled_distance"] = (df["traveled_distance"].map(int)) / 1000  # Down to km

    df["traveled_distance_bin"] = pd.cut(df["traveled_distance"] / 1000, distance_bins)
    df.loc[df["person"].str.contains("hgv"), "longest_distance_mode"] = "freight"
    df["longest_distance_mode"] = df["longest_distance_mode"].map(MODE_MAPPING)

    df["od_activities"] = df["start_activity_type"].str.split("_").str[0] + "-" + df["end_activity_type"].str.split("_").str[0]
    df['trip_purpose'] = df['od_activities'].apply(get_trip_purpose)

    return df

# %%
scenario_path = '/Users/tszchun.chow/Documents/GitHub/monty-data-visualization/pt_variations/baseline'
trip_df = read_trips(scenario_path)

# %%
trip_df.columns
# Out:
# Index(['person', 'trip_number', 'trip_id', 'dep_time', 'trav_time',
#        'wait_time', 'traveled_distance', 'euclidean_distance', 'main_mode',
#        'longest_distance_mode', 'modes', 'start_activity_type',
#        'end_activity_type', 'start_facility_id', 'start_link', 'start_x',
#        'start_y', 'end_facility_id', 'end_link', 'end_x', 'end_y',
#        'first_pt_boarding_stop', 'last_pt_egress_stop', 'start_sa2', 'end_sa2',
#        'start_regional_council', 'end_regional_council', 'person_id',
#        'household_id', 'home_region', 'home_sa2', 'age', 'gender',
#        'labour_force_status', 'student_status', 'hh_size', 'car_availability',
#        'is_working_from_home', 'income_group', 'age_group', 'period',
#        'traveled_distance_bin', 'od_activities', 'trip_purpose'],
#       dtype='object')

# %%
DEMOGRAPHIC_TYPE = ["gender", "age_group", "income_group", 
                   "labour_force_status", "student_status", "car_availability"]

# %%
groups = ['period', 'longest_distance_mode', 'trip_purpose', 'od', 'demo_type']
trips_metrics_dfs = []

def metrics_groupby(trip_df, subset_cols):
    logging.info(f"Grouping metrics for {str(subset_cols)}")
    trip_metrics_df = trip_df.groupby(subset_cols).agg(
        {'trip_id':'count', 'trav_time': 'mean', 'traveled_distance': 'mean'}).reset_index()
    
    demo_type = [i for i in subset_cols if i in DEMOGRAPHIC_TYPE]
    if len(demo_type) > 0:
        trip_metrics_df['demographic_type'] = demo_type[0]
        trip_metrics_df = trip_metrics_df.rename(columns={demo_type[0]: 'demographic_group'})

    return trip_metrics_df

for L in range(len(groups) + 1):
    for subset in itertools.combinations(groups, L):
        subset = [col for col in subset]
        if not subset:
             break 
        if ('demo_type' in subset) and ('od' in subset):
            for demo_type in DEMOGRAPHIC_TYPE:
                temp_subset_cols = subset.copy()
                temp_subset_cols[temp_subset_cols.index('demo_type')] = demo_type
                for od in ['start', 'end']:
                    subset_cols = temp_subset_cols.copy()
                    subset_cols[subset_cols.index('od')] = od+'_regional_council'

                    trips_metrics_dfs.append(metrics_groupby(trip_df, subset_cols))

        elif ('demo_type' in subset):
            for demo_type in DEMOGRAPHIC_TYPE:
                subset_cols = subset.copy()
                subset_cols[subset_cols.index('demo_type')] = demo_type

                trips_metrics_dfs.append(metrics_groupby(trip_df, subset_cols))

        elif ('od' in subset):
            for od in ['start', 'end']:
                subset_cols = subset.copy()
                subset_cols[subset_cols.index('od')] = od+'_regional_council'

                trips_metrics_dfs.append(metrics_groupby(trip_df, subset_cols))
                
        else:
            subset_cols = subset.copy()
            trips_metrics_dfs.append(metrics_groupby(trip_df, subset_cols))
# Out:
# 2023-12-12 12:14:43,002 - INFO - [3456935546.py:5] - Grouping metrics for ['period']
# 2023-12-12 12:14:43,178 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode']
# 2023-12-12 12:14:43,419 - INFO - [3456935546.py:5] - Grouping metrics for ['trip_purpose']
# 2023-12-12 12:14:43,610 - INFO - [3456935546.py:5] - Grouping metrics for ['start_regional_council']
# 2023-12-12 12:14:43,811 - INFO - [3456935546.py:5] - Grouping metrics for ['end_regional_council']
# 2023-12-12 12:14:44,009 - INFO - [3456935546.py:5] - Grouping metrics for ['gender']
# 2023-12-12 12:14:44,175 - INFO - [3456935546.py:5] - Grouping metrics for ['age_group']
# 2023-12-12 12:14:44,342 - INFO - [3456935546.py:5] - Grouping metrics for ['income_group']
# 2023-12-12 12:14:44,483 - INFO - [3456935546.py:5] - Grouping metrics for ['labour_force_status']
# 2023-12-12 12:14:44,656 - INFO - [3456935546.py:5] - Grouping metrics for ['student_status']
# 2023-12-12 12:14:44,834 - INFO - [3456935546.py:5] - Grouping metrics for ['car_availability']
# 2023-12-12 12:14:45,011 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode']
# 2023-12-12 12:14:45,296 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'trip_purpose']
# 2023-12-12 12:14:45,603 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'start_regional_council']
# 2023-12-12 12:14:45,899 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'end_regional_council']
# 2023-12-12 12:14:46,189 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'gender']
# 2023-12-12 12:14:46,452 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'age_group']
# 2023-12-12 12:14:46,720 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'income_group']
# 2023-12-12 12:14:46,971 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'labour_force_status']
# 2023-12-12 12:14:47,243 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'student_status']
# 2023-12-12 12:14:47,516 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'car_availability']
# 2023-12-12 12:14:47,790 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'trip_purpose']
# 2023-12-12 12:14:48,081 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'start_regional_council']
# 2023-12-12 12:14:48,386 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'end_regional_council']
# 2023-12-12 12:14:48,702 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'gender']
# 2023-12-12 12:14:48,978 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'age_group']
# 2023-12-12 12:14:49,253 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'income_group']
# 2023-12-12 12:14:49,504 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'labour_force_status']
# 2023-12-12 12:14:49,776 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'student_status']
# 2023-12-12 12:14:50,054 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'car_availability']
# 2023-12-12 12:14:50,336 - INFO - [3456935546.py:5] - Grouping metrics for ['trip_purpose', 'start_regional_council']
# 2023-12-12 12:14:50,647 - INFO - [3456935546.py:5] - Grouping metrics for ['trip_purpose', 'end_regional_council']
# 2023-12-12 12:14:50,960 - INFO - [3456935546.py:5] - Grouping metrics for ['trip_purpose', 'gender']
# 2023-12-12 12:14:51,253 - INFO - [3456935546.py:5] - Grouping metrics for ['trip_purpose', 'age_group']
# 2023-12-12 12:14:51,554 - INFO - [3456935546.py:5] - Grouping metrics for ['trip_purpose', 'income_group']
# 2023-12-12 12:14:51,830 - INFO - [3456935546.py:5] - Grouping metrics for ['trip_purpose', 'labour_force_status']
# 2023-12-12 12:14:52,139 - INFO - [3456935546.py:5] - Grouping metrics for ['trip_purpose', 'student_status']
# 2023-12-12 12:14:52,443 - INFO - [3456935546.py:5] - Grouping metrics for ['trip_purpose', 'car_availability']
# 2023-12-12 12:14:52,745 - INFO - [3456935546.py:5] - Grouping metrics for ['start_regional_council', 'gender']
# 2023-12-12 12:14:53,046 - INFO - [3456935546.py:5] - Grouping metrics for ['end_regional_council', 'gender']
# 2023-12-12 12:14:53,342 - INFO - [3456935546.py:5] - Grouping metrics for ['start_regional_council', 'age_group']
# 2023-12-12 12:14:53,644 - INFO - [3456935546.py:5] - Grouping metrics for ['end_regional_council', 'age_group']
# 2023-12-12 12:14:53,938 - INFO - [3456935546.py:5] - Grouping metrics for ['start_regional_council', 'income_group']
# 2023-12-12 12:14:54,210 - INFO - [3456935546.py:5] - Grouping metrics for ['end_regional_council', 'income_group']
# 2023-12-12 12:14:54,490 - INFO - [3456935546.py:5] - Grouping metrics for ['start_regional_council', 'labour_force_status']
# 2023-12-12 12:14:54,795 - INFO - [3456935546.py:5] - Grouping metrics for ['end_regional_council', 'labour_force_status']
# 2023-12-12 12:14:55,119 - INFO - [3456935546.py:5] - Grouping metrics for ['start_regional_council', 'student_status']
# 2023-12-12 12:14:55,442 - INFO - [3456935546.py:5] - Grouping metrics for ['end_regional_council', 'student_status']
# 2023-12-12 12:14:55,898 - INFO - [3456935546.py:5] - Grouping metrics for ['start_regional_council', 'car_availability']
# 2023-12-12 12:14:56,219 - INFO - [3456935546.py:5] - Grouping metrics for ['end_regional_council', 'car_availability']
# 2023-12-12 12:14:56,536 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'trip_purpose']
# 2023-12-12 12:14:56,910 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'start_regional_council']
# 2023-12-12 12:14:57,306 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'end_regional_council']
# 2023-12-12 12:14:57,717 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'gender']
# 2023-12-12 12:14:58,069 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'age_group']
# 2023-12-12 12:14:58,425 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'income_group']
# 2023-12-12 12:14:58,766 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'labour_force_status']
# 2023-12-12 12:14:59,119 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'student_status']
# 2023-12-12 12:14:59,466 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'car_availability']
# 2023-12-12 12:14:59,820 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'trip_purpose', 'start_regional_council']
# 2023-12-12 12:15:00,218 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'trip_purpose', 'end_regional_council']
# 2023-12-12 12:15:00,608 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'trip_purpose', 'gender']
# 2023-12-12 12:15:00,974 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'trip_purpose', 'age_group']
# 2023-12-12 12:15:01,354 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'trip_purpose', 'income_group']
# 2023-12-12 12:15:01,713 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'trip_purpose', 'labour_force_status']
# 2023-12-12 12:15:02,109 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'trip_purpose', 'student_status']
# 2023-12-12 12:15:02,482 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'trip_purpose', 'car_availability']
# 2023-12-12 12:15:02,855 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'start_regional_council', 'gender']
# 2023-12-12 12:15:03,231 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'end_regional_council', 'gender']
# 2023-12-12 12:15:03,631 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'start_regional_council', 'age_group']
# 2023-12-12 12:15:04,079 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'end_regional_council', 'age_group']
# 2023-12-12 12:15:04,464 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'start_regional_council', 'income_group']
# 2023-12-12 12:15:04,867 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'end_regional_council', 'income_group']
# 2023-12-12 12:15:05,240 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'start_regional_council', 'labour_force_status']
# 2023-12-12 12:15:05,628 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'end_regional_council', 'labour_force_status']
# 2023-12-12 12:15:06,016 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'start_regional_council', 'student_status']
# 2023-12-12 12:15:06,400 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'end_regional_council', 'student_status']
# 2023-12-12 12:15:06,779 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'start_regional_council', 'car_availability']
# 2023-12-12 12:15:07,163 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'end_regional_council', 'car_availability']
# 2023-12-12 12:15:07,544 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'trip_purpose', 'start_regional_council']
# 2023-12-12 12:15:07,948 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'trip_purpose', 'end_regional_council']
# 2023-12-12 12:15:08,356 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'trip_purpose', 'gender']
# 2023-12-12 12:15:08,735 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'trip_purpose', 'age_group']
# 2023-12-12 12:15:09,117 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'trip_purpose', 'income_group']
# 2023-12-12 12:15:09,479 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'trip_purpose', 'labour_force_status']
# 2023-12-12 12:15:09,861 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'trip_purpose', 'student_status']
# 2023-12-12 12:15:10,240 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'trip_purpose', 'car_availability']
# 2023-12-12 12:15:10,636 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'start_regional_council', 'gender']
# 2023-12-12 12:15:11,035 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'end_regional_council', 'gender']
# 2023-12-12 12:15:11,430 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'start_regional_council', 'age_group']
# 2023-12-12 12:15:11,822 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'end_regional_council', 'age_group']
# 2023-12-12 12:15:12,208 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'start_regional_council', 'income_group']
# 2023-12-12 12:15:12,576 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'end_regional_council', 'income_group']
# 2023-12-12 12:15:12,942 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'start_regional_council', 'labour_force_status']
# 2023-12-12 12:15:13,334 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'end_regional_council', 'labour_force_status']
# 2023-12-12 12:15:13,749 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'start_regional_council', 'student_status']
# 2023-12-12 12:15:14,150 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'end_regional_council', 'student_status']
# 2023-12-12 12:15:14,543 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'start_regional_council', 'car_availability']
# 2023-12-12 12:15:14,937 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'end_regional_council', 'car_availability']
# 2023-12-12 12:15:15,333 - INFO - [3456935546.py:5] - Grouping metrics for ['trip_purpose', 'start_regional_council', 'gender']
# 2023-12-12 12:15:15,740 - INFO - [3456935546.py:5] - Grouping metrics for ['trip_purpose', 'end_regional_council', 'gender']
# 2023-12-12 12:15:16,143 - INFO - [3456935546.py:5] - Grouping metrics for ['trip_purpose', 'start_regional_council', 'age_group']
# 2023-12-12 12:15:16,553 - INFO - [3456935546.py:5] - Grouping metrics for ['trip_purpose', 'end_regional_council', 'age_group']
# 2023-12-12 12:15:16,965 - INFO - [3456935546.py:5] - Grouping metrics for ['trip_purpose', 'start_regional_council', 'income_group']
# 2023-12-12 12:15:17,352 - INFO - [3456935546.py:5] - Grouping metrics for ['trip_purpose', 'end_regional_council', 'income_group']
# 2023-12-12 12:15:17,740 - INFO - [3456935546.py:5] - Grouping metrics for ['trip_purpose', 'start_regional_council', 'labour_force_status']
# 2023-12-12 12:15:18,150 - INFO - [3456935546.py:5] - Grouping metrics for ['trip_purpose', 'end_regional_council', 'labour_force_status']
# 2023-12-12 12:15:18,561 - INFO - [3456935546.py:5] - Grouping metrics for ['trip_purpose', 'start_regional_council', 'student_status']
# 2023-12-12 12:15:18,971 - INFO - [3456935546.py:5] - Grouping metrics for ['trip_purpose', 'end_regional_council', 'student_status']
# 2023-12-12 12:15:19,380 - INFO - [3456935546.py:5] - Grouping metrics for ['trip_purpose', 'start_regional_council', 'car_availability']
# 2023-12-12 12:15:19,791 - INFO - [3456935546.py:5] - Grouping metrics for ['trip_purpose', 'end_regional_council', 'car_availability']
# 2023-12-12 12:15:20,197 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'trip_purpose', 'start_regional_council']
# 2023-12-12 12:15:20,681 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'trip_purpose', 'end_regional_council']
# 2023-12-12 12:15:21,167 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'trip_purpose', 'gender']
# 2023-12-12 12:15:21,625 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'trip_purpose', 'age_group']
# 2023-12-12 12:15:22,087 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'trip_purpose', 'income_group']
# 2023-12-12 12:15:22,524 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'trip_purpose', 'labour_force_status']
# 2023-12-12 12:15:22,990 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'trip_purpose', 'student_status']
# 2023-12-12 12:15:23,453 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'trip_purpose', 'car_availability']
# 2023-12-12 12:15:23,918 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'start_regional_council', 'gender']
# 2023-12-12 12:15:24,379 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'end_regional_council', 'gender']
# 2023-12-12 12:15:24,835 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'start_regional_council', 'age_group']
# 2023-12-12 12:15:25,300 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'end_regional_council', 'age_group']
# 2023-12-12 12:15:25,777 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'start_regional_council', 'income_group']
# 2023-12-12 12:15:26,229 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'end_regional_council', 'income_group']
# 2023-12-12 12:15:26,680 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'start_regional_council', 'labour_force_status']
# 2023-12-12 12:15:27,143 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'end_regional_council', 'labour_force_status']
# 2023-12-12 12:15:27,611 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'start_regional_council', 'student_status']
# 2023-12-12 12:15:28,081 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'end_regional_council', 'student_status']
# 2023-12-12 12:15:28,543 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'start_regional_council', 'car_availability']
# 2023-12-12 12:15:29,010 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'end_regional_council', 'car_availability']
# 2023-12-12 12:15:29,468 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'trip_purpose', 'start_regional_council', 'gender']
# 2023-12-12 12:15:29,944 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'trip_purpose', 'end_regional_council', 'gender']
# 2023-12-12 12:15:30,428 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'trip_purpose', 'start_regional_council', 'age_group']
# 2023-12-12 12:15:30,912 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'trip_purpose', 'end_regional_council', 'age_group']
# 2023-12-12 12:15:31,402 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'trip_purpose', 'start_regional_council', 'income_group']
# 2023-12-12 12:15:31,867 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'trip_purpose', 'end_regional_council', 'income_group']
# 2023-12-12 12:15:32,334 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'trip_purpose', 'start_regional_council', 'labour_force_status']
# 2023-12-12 12:15:32,820 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'trip_purpose', 'end_regional_council', 'labour_force_status']
# 2023-12-12 12:15:33,314 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'trip_purpose', 'start_regional_council', 'student_status']
# 2023-12-12 12:15:33,809 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'trip_purpose', 'end_regional_council', 'student_status']
# 2023-12-12 12:15:34,302 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'trip_purpose', 'start_regional_council', 'car_availability']
# 2023-12-12 12:15:34,788 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'trip_purpose', 'end_regional_council', 'car_availability']
# 2023-12-12 12:15:35,277 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'trip_purpose', 'start_regional_council', 'gender']
# 2023-12-12 12:15:35,763 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'trip_purpose', 'end_regional_council', 'gender']
# 2023-12-12 12:15:36,250 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'trip_purpose', 'start_regional_council', 'age_group']
# 2023-12-12 12:15:36,743 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'trip_purpose', 'end_regional_council', 'age_group']
# 2023-12-12 12:15:37,236 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'trip_purpose', 'start_regional_council', 'income_group']
# 2023-12-12 12:15:37,717 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'trip_purpose', 'end_regional_council', 'income_group']
# 2023-12-12 12:15:38,185 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'trip_purpose', 'start_regional_council', 'labour_force_status']
# 2023-12-12 12:15:38,686 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'trip_purpose', 'end_regional_council', 'labour_force_status']
# 2023-12-12 12:15:39,193 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'trip_purpose', 'start_regional_council', 'student_status']
# 2023-12-12 12:15:39,709 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'trip_purpose', 'end_regional_council', 'student_status']
# 2023-12-12 12:15:40,223 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'trip_purpose', 'start_regional_council', 'car_availability']
# 2023-12-12 12:15:40,741 - INFO - [3456935546.py:5] - Grouping metrics for ['longest_distance_mode', 'trip_purpose', 'end_regional_council', 'car_availability']
# 2023-12-12 12:15:41,247 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'trip_purpose', 'start_regional_council', 'gender']
# 2023-12-12 12:15:41,815 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'trip_purpose', 'end_regional_council', 'gender']
# 2023-12-12 12:15:42,385 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'trip_purpose', 'start_regional_council', 'age_group']
# 2023-12-12 12:15:42,964 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'trip_purpose', 'end_regional_council', 'age_group']
# 2023-12-12 12:15:43,550 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'trip_purpose', 'start_regional_council', 'income_group']
# 2023-12-12 12:15:44,111 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'trip_purpose', 'end_regional_council', 'income_group']
# 2023-12-12 12:15:44,673 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'trip_purpose', 'start_regional_council', 'labour_force_status']
# 2023-12-12 12:15:45,266 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'trip_purpose', 'end_regional_council', 'labour_force_status']
# 2023-12-12 12:15:45,868 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'trip_purpose', 'start_regional_council', 'student_status']
# 2023-12-12 12:15:46,449 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'trip_purpose', 'end_regional_council', 'student_status']
# 2023-12-12 12:15:47,036 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'trip_purpose', 'start_regional_council', 'car_availability']
# 2023-12-12 12:15:47,630 - INFO - [3456935546.py:5] - Grouping metrics for ['period', 'longest_distance_mode', 'trip_purpose', 'end_regional_council', 'car_availability']

# %%
trips_metrics_summary= pd.concat(trips_metrics_dfs, axis = 0, join='outer'
                            ).rename(columns={'trip_id': 'trip_count',
                                            'longest_distance_mode': 'mode',
                                            'trav_time': 'travel_time'
                                            }
                            )

category_cols = ['period', 'mode', 'trip_purpose', 'start_regional_council', 'end_regional_council', 'demographic_type', 'demographic_group']
#category_cols = list(set(trips_metrics_summary.columns) - set(['trip_count', 'travel_time', 'traveled_distance']))

trips_metrics_summary = trips_metrics_summary.fillna("All")
trips_metrics_summary['period'] = trips_metrics_summary['period'].fillna("Daily")
trips_metrics_summary.melt(id_vars=category_cols, 
                            var_name="Metric", 
                            value_name="Value")
#trips_metrics_summary.to_csv('tripmetrics.csv', index=None)
# Out:
#        period    mode    trip_purpose start_regional_council  \
# 0          AM     All             All                    All
# 1          IP     All             All                    All
# 2          OP     All             All                    All
# 3          PM     All             All                    All
# 4         All  active             All                    All
# ...       ...     ...             ...                    ...
# 215248     PM      pv  non home-based                    All
# 215249     PM      pv  non home-based                    All
# 215250     PM      pv  non home-based                    All
# 215251     PM      pv  non home-based                    All
# 215252     PM      pv  non home-based                    All
#
#        end_regional_council  demographic_type demographic_group  \
# 0                       All               All               All
# 1                       All               All               All
# 2                       All               All               All
# 3                       All               All               All
# 4                       All               All               All
# ...                     ...               ...               ...
# 215248       Waikato Region  car_availability             Never
# 215249    Wellington Region  car_availability            Always
# 215250    Wellington Region  car_availability             Never
# 215251    West Coast Region  car_availability            Always
# 215252    West Coast Region  car_availability             Never
#
#                    Metric          Value
# 0              trip_count  262987.000000
# 1              trip_count  763372.000000
# 2              trip_count  295565.000000
# 3              trip_count  426503.000000
# 4              trip_count  203951.000000
# ...                   ...            ...
# 215248  traveled_distance       7.225890
# 215249  traveled_distance       4.567347
# 215250  traveled_distance       4.975395
# 215251  traveled_distance       6.429346
# 215252  traveled_distance      10.133111
#
# [215253 rows x 9 columns]
